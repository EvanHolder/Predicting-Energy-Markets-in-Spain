# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/NBA_PBP_2015-16.csv')

# %%
df.head()
# Out:
#                             URL GameType                       Location  \
# 0  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 1  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 2  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 3  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 4  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
#
#               Date     Time WinningTeam  Quarter  SecLeft AwayTeam  \
# 0  October 27 2015  8:00 PM         DET        1      720      DET
# 1  October 27 2015  8:00 PM         DET        1      701      DET
# 2  October 27 2015  8:00 PM         DET        1      699      DET
# 3  October 27 2015  8:00 PM         DET        1      697      DET
# 4  October 27 2015  8:00 PM         DET        1      681      DET
#
#                                             AwayPlay  ...  FreeThrowNum  \
# ...

# %%
df.shape
# Out:
# (601557, 40)

# %%
df.nunique()
# Out:
# URL                    1316
# GameType                  2
# Location                 31
# Date                    210
# Time                     21
# WinningTeam              30
# Quarter                   8
# SecLeft                 721
# AwayTeam                 30
# AwayPlay              87361
# AwayScore               145
# HomeTeam                 30
# HomePlay              83702
# HomeScore               144
# Shooter                 477
# ShotType                  7
# ShotOutcome               2
# ShotDist                 89
# Assister                462
# Blocker                 444
# FoulType                 14
# Fouler                  475
# Fouled                  465
# Rebounder               475
# ReboundType               2
# ViolationPlayer         358
# ViolationType             6
# TimeoutTeam              30
# FreeThrowShooter        464
# FreeThrowOutcome          2
# FreeThrowNum              7
# EnterGame               478
# LeaveGame               471
# ...

# %%
df.AwayTeam.unique()
# Out:
# array(['DET', 'CLE', 'NOP', 'WAS', 'PHI', 'CHI', 'UTA', 'CHO', 'IND',
#        'DEN', 'NYK', 'SAS', 'DAL', 'LAC', 'MIN', 'MEM', 'ATL', 'MIA',
#        'OKC', 'TOR', 'BRK', 'GSW', 'LAL', 'POR', 'PHO', 'SAC', 'HOU',
#        'MIL', 'ORL', 'BOS'], dtype=object)

# %%
u_shooters = set(df.Shooter.unique())

# %%
df.Shooter.nunique()
# Out:
# 477

# %%
u_InGame = set(df.EnterGame.unique())

# %%
u_InGame - u_shooters
# Out:
# {'S. Dekker - dekkesa01'}

# %%
df.iloc[:,0:20]
# Out:
#                                  URL GameType  \
# 0       /boxscores/201510270ATL.html  regular
# 1       /boxscores/201510270ATL.html  regular
# 2       /boxscores/201510270ATL.html  regular
# 3       /boxscores/201510270ATL.html  regular
# 4       /boxscores/201510270ATL.html  regular
# ...                              ...      ...
# 601552  /boxscores/201606190GSW.html  playoff
# 601553  /boxscores/201606190GSW.html  playoff
# 601554  /boxscores/201606190GSW.html  playoff
# 601555  /boxscores/201606190GSW.html  playoff
# 601556  /boxscores/201606190GSW.html  playoff
#
#                                Location             Date     Time WinningTeam  \
# 0         Philips Arena Atlanta Georgia  October 27 2015  8:00 PM         DET
# 1         Philips Arena Atlanta Georgia  October 27 2015  8:00 PM         DET
# 2         Philips Arena Atlanta Georgia  October 27 2015  8:00 PM         DET
# 3         Philips Arena Atlanta Georgia  October 27 2015  8:00 PM         DET
# ...

# %%
df.iloc[:,20:]
# Out:
#        FoulType Fouler Fouled                Rebounder ReboundType  \
# 0           NaN    NaN    NaN                      NaN         NaN
# 1           NaN    NaN    NaN                      NaN         NaN
# 2           NaN    NaN    NaN  K. Bazemore - bazemke01   defensive
# 3           NaN    NaN    NaN                      NaN         NaN
# 4           NaN    NaN    NaN                      NaN         NaN
# ...         ...    ...    ...                      ...         ...
# 601552      NaN    NaN    NaN  M. Speights - speigma01   offensive
# 601553      NaN    NaN    NaN                      NaN         NaN
# 601554      NaN    NaN    NaN                     Team   offensive
# 601555      NaN    NaN    NaN                      NaN         NaN
# 601556      NaN    NaN    NaN                      NaN         NaN
#
#        ViolationPlayer ViolationType TimeoutTeam FreeThrowShooter  \
# 0                  NaN           NaN         NaN              NaN
# ...
